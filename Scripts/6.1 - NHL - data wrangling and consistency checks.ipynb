# %%
#Import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Timbr\OneDrive\Desktop\Career Foundry\Data Immersion\Achievement 6'

# %%
#import 'NHL_Data_2008-2022_kaggle.csv' to make df_kaggle
df_kaggle = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'NHL_Data_2008-2022_kaggle.csv'), index_col = False)

# %%
#import 'NHL_Data_2008-2022_Nat_Stat_Trick.csv' to make df_Nat_Stat_Trick
df_Nat_Stat_Trick = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'NHL_Data_2008-2022_Nat_Stat_Trick.csv'), index_col = False,low_memory=False)

# %%
#import 'Schedule - Results_2008-2002_Hockey-Reference.csv' to make df_Results
df_Results = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'Schedule - Results_2008-2002_Hockey-Reference.csv'), index_col = False,low_memory=False)

# %% [markdown]
# # df_kaggle Check

# %%
#check head
df_kaggle.head(10)
# Out:
#   Team-Date Combined for Vlookup team  season name      gameId playerTeam  \
# 0                   NYR-20081004  NYR    2008  NYR  2008020001        NYR
# 1                   NYR-20081004  NYR    2008  NYR  2008020001        NYR
# 2                   NYR-20081005  NYR    2008  NYR  2008020003        NYR
# 3                   NYR-20081005  NYR    2008  NYR  2008020003        NYR
# 4                   NYR-20081010  NYR    2008  NYR  2008020010        NYR
# 5                   NYR-20081010  NYR    2008  NYR  2008020010        NYR
# 6                   NYR-20081011  NYR    2008  NYR  2008020019        NYR
# 7                   NYR-20081011  NYR    2008  NYR  2008020019        NYR
# 8                   NYR-20081013  NYR    2008  NYR  2008020034        NYR
# 9                   NYR-20081013  NYR    2008  NYR  2008020034        NYR
#
#   opposingTeam home_or_away  gameDate    position  ...  \
# 0          TBL         AWAY  20081004  Team Level  ...
# ...

# %%
df_kaggle.describe()
# Out:
#              season        gameId      gameDate  xGoalsPercentage  \
# count  70688.000000  7.068800e+04  7.068800e+04      70688.000000
# mean    2015.024106  2.015045e+09  2.015662e+07          0.500000
# std        4.358500  4.358503e+06  4.398750e+04          0.115794
# min     2008.000000  2.008020e+09  2.008100e+07          0.084100
# 25%     2011.000000  2.011021e+09  2.012012e+07          0.420100
# 50%     2015.000000  2.015021e+09  2.016016e+07          0.500000
# 75%     2019.000000  2.019020e+09  2.019102e+07          0.579900
# max     2022.000000  2.022021e+09  2.023041e+07          0.915900
#
#        corsiPercentage  fenwickPercentage       iceTime    xOnGoalFor  \
# count     70688.000000       70688.000000  70688.000000  70688.000000
# mean          0.500000           0.500000   3280.163988     26.826011
# std           0.080811           0.083082    434.763948      6.924725
# min           0.171400           0.155200      0.000000      0.000000
# ...

# %%
#check for missing values
df_kaggle.isnull().sum()
# Out:
# Team-Date Combined for Vlookup               0
# team                                         0
# season                                       0
# name                                         0
# gameId                                       0
#                                             ..
# reboundxGoalsAgainst                         0
# totalShotCreditAgainst                       0
# scoreAdjustedTotalShotCreditAgainst          0
# scoreFlurryAdjustedTotalShotCreditAgainst    0
# playoffGame                                  0
# Length: 112, dtype: int64

# %%
# Check for duplicates
df_kaggle_dups = df_kaggle[df_kaggle.duplicated()]

# %%
df_kaggle_dups
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # df_Nat_Stat_Trick Check

# %%
#check head
df_Nat_Stat_Trick.head(10)
# Out:
#   Team-Date Combined for Vlookup                          Game (origional)  \
# 0                   NYR-20081004       2008-10-04 - Rangers 2, Lightning 1
# 1                   TBL-20081004       2008-10-04 - Rangers 2, Lightning 1
# 2                   OTT-20081004       2008-10-04 - Penguins 4, Senators 3
# 3                   PIT-20081004       2008-10-04 - Penguins 4, Senators 3
# 4                   NYR-20081005       2008-10-05 - Lightning 1, Rangers 2
# 5                   TBL-20081005       2008-10-05 - Lightning 1, Rangers 2
# 6                   OTT-20081005       2008-10-05 - Senators 3, Penguins 1
# 7                   PIT-20081005       2008-10-05 - Senators 3, Penguins 1
# 8                   DET-20081009   2008-10-09 - Maple Leafs 3, Red Wings 2
# 9                   TOR-20081009   2008-10-09 - Maple Leafs 3, Red Wings 2
#
#         Date  Year  Month  Day  Date Combined                     matchup  \
# ...

# %%
df_Nat_Stat_Trick.describe()
# Out:
#                Year         Month           Day  Date Combined           TOI  \
# count  70704.000000  70704.000000  70704.000000   7.070400e+04  70704.000000
# mean    2015.598721      6.062344     15.383684   2.015661e+07     54.264520
# std        4.405386      4.404349      8.740666   4.399544e+04      7.386737
# min     2008.000000      1.000000      1.000000   2.008100e+07     26.533333
# 25%     2012.000000      2.000000      8.000000   2.012012e+07     47.966667
# 50%     2016.000000      4.000000     15.000000   2.016013e+07     60.000000
# 75%     2019.000000     11.000000     23.000000   2.019102e+07     60.000000
# max     2023.000000     12.000000     31.000000   2.023041e+07     76.800000
#
#                  CF            CA           CF%            FF            FA  \
# count  70704.000000  70704.000000  70704.000000  70704.000000  70704.000000
# mean      50.015049     50.015049     50.000025     37.461077     37.461077
# ...

# %%
#check for missing values
df_Nat_Stat_Trick.isnull().sum()
# Out:
# Team-Date Combined for Vlookup    0
# Game (origional)                  0
# Date                              0
# Year                              0
# Month                             0
#                                  ..
# SH%                               0
# SV%                               0
# PDO                               0
# Attendance                        0
# situation                         0
# Length: 67, dtype: int64

# %%
# Check for duplicates
df_Nat_Stat_Trick_dups = df_Nat_Stat_Trick[df_Nat_Stat_Trick.duplicated()]

# %%
df_kaggle_dups
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # df_Results Check

# %%
#check head
df_Results.head(10)
# Out:
#          Date  Year  Month  Day  Date Combined                Visitor  \
# 0   10/7/2022  2022     10    7       20221007        San Jose Sharks
# 1   10/8/2022  2022     10    8       20221008    Nashville Predators
# 2  10/11/2022  2022     10   11       20221011   Vegas Golden Knights
# 3  10/11/2022  2022     10   11       20221011    Tampa Bay Lightning
# 4  10/12/2022  2022     10   12       20221012         Seattle Kraken
# 5  10/12/2022  2022     10   12       20221012  Columbus Blue Jackets
# 6  10/12/2022  2022     10   12       20221012     Chicago Blackhawks
# 7  10/12/2022  2022     10   12       20221012      Vancouver Canucks
# 8  10/12/2022  2022     10   12       20221012    Toronto Maple Leafs
# 9  10/12/2022  2022     10   12       20221012          Boston Bruins
#
#   Abbreviation Visitor-Team-Date Combined for Vlookup  G - Visitor  \
# 0          SJS                           SJS-20221007          1.0
# ...

# %%
df_Results.describe()
# Out:
#                Year         Month           Day  Date Combined   G - Visitor  \
# count  17677.000000  17677.000000  17677.000000   1.767700e+04  17676.000000
# mean    2015.598631      6.062058     15.384172   2.015661e+07      2.750905
# std        4.405371      4.404482      8.740844   4.399530e+04      1.625160
# min     2008.000000      1.000000      1.000000   2.008100e+07      0.000000
# 25%     2012.000000      2.000000      8.000000   2.012012e+07      2.000000
# 50%     2016.000000      4.000000     15.000000   2.016013e+07      3.000000
# 75%     2019.000000     11.000000     23.000000   2.019102e+07      4.000000
# max     2023.000000     12.000000     31.000000   2.023041e+07     10.000000
#
#            G - Home           Att.
# count  17676.000000   17108.000000
# mean       3.022630   17052.429916
# std        1.707409    3664.736562
# min        0.000000     100.000000
# 25%        2.000000   16002.000000
# 50%        3.000000   17850.000000
# ...

# %%
#check for missing values
df_Results.isnull().sum()
# Out:
# Date                                          0
# Year                                          0
# Month                                         0
# Day                                           0
# Date Combined                                 0
# Visitor                                       0
# Abbreviation                                  0
# Visitor-Team-Date Combined for Vlookup        0
# G - Visitor                                   1
# Home                                          0
# Abbreviation.1                                0
# Home-Team-Date Combined for Vlookup           0
# G - Home                                      1
# OT                                        13556
# Att.                                        569
# LOG                                        8102
# Notes                                     17496
# dtype: int64

# %%
# Check for duplicates
df_Results_dups = df_Results[df_Results.duplicated()]

# %%
df_Results_dups
# Out:
# Empty DataFrame
# Columns: [Date, Year, Month, Day, Date Combined, Visitor, Abbreviation, Visitor-Team-Date Combined for Vlookup, G - Visitor, Home, Abbreviation.1, Home-Team-Date Combined for Vlookup, G - Home, OT, Att., LOG, Notes]
# Index: []

# %% [markdown]
# # Export Clean Data

# %%
#Export df_kaggle
df_kaggle.to_csv(os.path.join(path, 'Data', 'Cleaned Data', 'kaggle_checked.csv'))

# %%
#Export df_Nat_Stat_Trick
df_Nat_Stat_Trick.to_csv(os.path.join(path, 'Data', 'Cleaned Data', 'Nat_Stat_Trick_checked.csv'))

# %%
#Export df_Results
df_Results.to_csv(os.path.join(path, 'Data', 'Cleaned Data', 'Results_checked.csv'))
